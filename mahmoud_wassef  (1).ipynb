# %%
tshirt=100
jacket=300
skirt=250
total_coast = tshirt+jacket+skirt
print(total_coast)
budget=1000
compare_between_total_coast_and_budget = total_coast < budget
print(compare_between_total_coast_and_budget)
money_left=budget-total_coast
print(money_left)
# Out:
# 650
# True
# 350
